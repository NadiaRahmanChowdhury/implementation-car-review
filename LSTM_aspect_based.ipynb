# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from keras.layers import Input
from tensorflow.keras.utils import pad_sequences
from keras.callbacks import ModelCheckpoint
import pandas as pd
import numpy as np
import re
import nltk
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
from keras.preprocessing.text import Tokenizer
from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dense, concatenate, Dropout
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.metrics import roc_curve, auc
from keras.models import Model

# %%
df = pd.read_excel('/content/drive/MyDrive/aspect_sentiment_dataset_final.xlsx')
df = df.drop(columns=['Unnamed: 0'], axis=1)
df[:10]
# Out:
#    Unnamed: 0.1                                             review  \
# 0             0   I bought mine 4/17 with 98K. Have been wantin...
# 1             1   I bought mine 4/17 with 98K. Have been wantin...
# 2             2   I bought mine 4/17 with 98K. Have been wantin...
# 3             3   I bought mine 4/17 with 98K. Have been wantin...
# 4             4   Lots of problems with Ford these days, sensor...
# 5             5   Bought mine used 20k on it and have added a S...
# 6             6   Bought mine used 20k on it and have added a S...
# 7             7   I drive 50 miles each way to work and traded ...
# 8             8   I drive 50 miles each way to work and traded ...
# 9            10   This car is just awesome.  The 4.6L V8 makes ...
#
#                                     annotated_review       aspect  \
# 0   I bought mine 4/17 with 98K. Have been wantin...  performance
# 1   I bought mine 4/17 with 98K. Have been wantin...       engine
# 2   I bought mine 4/17 with 98K. Have been wantin...        power
# 3   I bought mine 4/17 with 98K. Have been wantin...      mileage
# 4   Lots of problems with Ford these days, [senso...      sensors
# 5   Bought mine used 20k on it and have added a S...  performance
# 6   Bought mine used 20k on it and have added a S...      comfort
# 7   I drive 50 miles each way to work and traded ...  performance
# 8   I drive 50 miles each way to work and traded ...       engine
# 9   This car is just awesome.  The 4.6L V8 makes ...        price
#
#   aspect_sentiment
# 0         negative
# 1         negative
# 2         negative
# 3         negative
# 4          neutral
# 5         negative
# 6          neutral
# 7          neutral
# 8         negative
# 9          neutral

# %%
# Preprocessing
nltk.download('stopwords')
stop_words = stopwords.words('english')

def preprocess_text(text):
    text = re.sub('[^a-zA-Z]', ' ', text)  # Remove punctuations
    text = text.lower()  # Convert to lowercase
    text = ' '.join([word for word in text.split() if word not in stop_words])  # Remove stopwords
    return text
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
df['review'] = df['review'].apply(preprocess_text)
df['aspect'] = df['aspect'].apply(preprocess_text)

# Tokenization
tokenizer = Tokenizer(num_words=5000)
tokenizer.fit_on_texts(df['review'].values + df['aspect'].values)

X_review = tokenizer.texts_to_sequences(df['review'].values)
X_aspect = tokenizer.texts_to_sequences(df['aspect'].values)

# Padding
max_sequence_length = 100
X_review = pad_sequences(X_review, maxlen=max_sequence_length)
X_aspect = pad_sequences(X_aspect, maxlen=max_sequence_length)

# Label encoding
y = pd.get_dummies(df['aspect_sentiment']).values

# %%
# Train-test split
X_train_review, X_test_review, X_train_aspect, X_test_aspect, y_train, y_test = train_test_split(
    X_review, X_aspect, y, test_size=0.2, random_state=42)

# %%
from keras.models import Model
from keras.layers import Input, Embedding, LSTM, concatenate, Dropout, Dense
from keras.regularizers import l2

embedding_dim = 100
vocab_size = len(tokenizer.word_index) + 1

# Review input branch
review_input = Input(shape=(max_sequence_length,))
review_embedding = Embedding(vocab_size, embedding_dim, input_length=max_sequence_length)(review_input)
review_lstm = LSTM(64, return_sequences=True, kernel_regularizer=l2(0.01))(review_embedding)
review_lstm = LSTM(128, return_sequences=True, kernel_regularizer=l2(0.01))(review_lstm)

# Aspect input branch
aspect_input = Input(shape=(max_sequence_length,))
aspect_embedding = Embedding(vocab_size, embedding_dim, input_length=max_sequence_length)(aspect_input)
aspect_lstm = LSTM(64, return_sequences=True, kernel_regularizer=l2(0.01))(aspect_embedding)
aspect_lstm = LSTM(128, return_sequences=True, kernel_regularizer=l2(0.01))(aspect_lstm)

# Merge review and aspect branches
merged = concatenate([review_lstm, aspect_lstm])
lstm = LSTM(128, kernel_regularizer=l2(0.01))(merged)
dense = Dropout(0.2)(lstm)
dense = Dense(64, activation='relu', kernel_regularizer=l2(0.01))(dense)
dense = Dropout(0.2)(dense)
output = Dense(3, activation='softmax')(dense)

model = Model(inputs=[review_input, aspect_input], outputs=output)
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
print(model.summary())
# Accuracy: 75.05%
# Epoch = 20 76%
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 100)]                0         []
#
#  input_2 (InputLayer)        [(None, 100)]                0         []
#
#  embedding (Embedding)       (None, 100, 100)             2330600   ['input_1[0][0]']
#
#  embedding_1 (Embedding)     (None, 100, 100)             2330600   ['input_2[0][0]']
#
#  lstm (LSTM)                 (None, 100, 64)              42240     ['embedding[0][0]']
#
#  lstm_2 (LSTM)               (None, 100, 64)              42240     ['embedding_1[0][0]']
#
#  lstm_1 (LSTM)               (None, 100, 128)             98816     ['lstm[0][0]']
#
#  lstm_3 (LSTM)               (None, 100, 128)             98816     ['lstm_2[0][0]']
#
#  concatenate (Concatenate)   (None, 100, 256)             0         ['lstm_1[0][0]',
#                                                                      'lstm_3[0][0]']
#
#  lstm_4 (LSTM)               (None, 128)                  197120    ['concatenate[0][0]']
#
#  dropout (Dropout)           (None, 128)                  0         ['lstm_4[0][0]']
#
#  dense (Dense)               (None, 64)                   8256      ['dropout[0][0]']
#
#  dropout_1 (Dropout)         (None, 64)                   0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 3)                    195       ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 5148883 (19.64 MB)
# Trainable params: 5148883 (19.64 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# None

# %%
# Train the model
# Train the model
epochs = 20 #10
batch_size = 32
checkpoint = ModelCheckpoint('lstm_model.hdf5', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
history = model.fit([X_train_review, X_train_aspect], y_train, validation_data=([X_test_review, X_test_aspect], y_test),
                    epochs=epochs, batch_size=batch_size, callbacks=[checkpoint])
# Out:
# Epoch 1/20
# 262/262 [==============================] - ETA: 0s - loss: 2.0935 - accuracy: 0.6219
# Epoch 1: val_accuracy improved from -inf to 0.67511, saving model to lstm_model.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 262/262 [==============================] - 185s 659ms/step - loss: 2.0935 - accuracy: 0.6219 - val_loss: 0.8465 - val_accuracy: 0.6751
# Epoch 2/20
# 262/262 [==============================] - ETA: 0s - loss: 0.7712 - accuracy: 0.6923
# Epoch 2: val_accuracy did not improve from 0.67511
# 262/262 [==============================] - 181s 689ms/step - loss: 0.7712 - accuracy: 0.6923 - val_loss: 0.8364 - val_accuracy: 0.6421
# Epoch 3/20
# 262/262 [==============================] - ETA: 0s - loss: 0.6983 - accuracy: 0.7278
# Epoch 3: val_accuracy improved from 0.67511 to 0.68753, saving model to lstm_model.hdf5
# 262/262 [==============================] - 178s 680ms/step - loss: 0.6983 - accuracy: 0.7278 - val_loss: 0.7921 - val_accuracy: 0.6875
# Epoch 4/20
# 262/262 [==============================] - ETA: 0s - loss: 0.6507 - accuracy: 0.7567
# Epoch 4: val_accuracy improved from 0.68753 to 0.69852, saving model to lstm_model.hdf5
# 262/262 [==============================] - 168s 638ms/step - loss: 0.6507 - accuracy: 0.7567 - val_loss: 0.7803 - val_accuracy: 0.6985
# Epoch 5/20
# 262/262 [==============================] - ETA: 0s - loss: 0.6225 - accuracy: 0.7734
# Epoch 5: val_accuracy did not improve from 0.69852
# 262/262 [==============================] - 177s 675ms/step - loss: 0.6225 - accuracy: 0.7734 - val_loss: 0.8286 - val_accuracy: 0.6847
# Epoch 6/20
# 262/262 [==============================] - ETA: 0s - loss: 0.6301 - accuracy: 0.7718
# Epoch 6: val_accuracy improved from 0.69852 to 0.70139, saving model to lstm_model.hdf5
# 262/262 [==============================] - 167s 638ms/step - loss: 0.6301 - accuracy: 0.7718 - val_loss: 0.8424 - val_accuracy: 0.7014
# Epoch 7/20
# 262/262 [==============================] - ETA: 0s - loss: 0.6217 - accuracy: 0.7783
# Epoch 7: val_accuracy did not improve from 0.70139
# 262/262 [==============================] - 176s 669ms/step - loss: 0.6217 - accuracy: 0.7783 - val_loss: 0.7981 - val_accuracy: 0.6885
# Epoch 8/20
# 262/262 [==============================] - ETA: 0s - loss: 0.5979 - accuracy: 0.7973
# Epoch 8: val_accuracy did not improve from 0.70139
# 262/262 [==============================] - 165s 631ms/step - loss: 0.5979 - accuracy: 0.7973 - val_loss: 0.8824 - val_accuracy: 0.6961
# Epoch 9/20
# 262/262 [==============================] - ETA: 0s - loss: 0.5956 - accuracy: 0.7966
# Epoch 9: val_accuracy improved from 0.70139 to 0.70712, saving model to lstm_model.hdf5
# 262/262 [==============================] - 178s 681ms/step - loss: 0.5956 - accuracy: 0.7966 - val_loss: 0.8242 - val_accuracy: 0.7071
# Epoch 10/20
# 262/262 [==============================] - ETA: 0s - loss: 0.5529 - accuracy: 0.8172
# Epoch 10: val_accuracy did not improve from 0.70712
# 262/262 [==============================] - 168s 640ms/step - loss: 0.5529 - accuracy: 0.8172 - val_loss: 0.9233 - val_accuracy: 0.6842
# Epoch 11/20
# 262/262 [==============================] - ETA: 0s - loss: 0.5363 - accuracy: 0.8279
# Epoch 11: val_accuracy improved from 0.70712 to 0.71429, saving model to lstm_model.hdf5
# 262/262 [==============================] - 168s 639ms/step - loss: 0.5363 - accuracy: 0.8279 - val_loss: 0.8144 - val_accuracy: 0.7143
# Epoch 12/20
# 262/262 [==============================] - ETA: 0s - loss: 0.5366 - accuracy: 0.8403
# Epoch 12: val_accuracy did not improve from 0.71429
# 262/262 [==============================] - 178s 678ms/step - loss: 0.5366 - accuracy: 0.8403 - val_loss: 0.9620 - val_accuracy: 0.7119
# Epoch 13/20
# 262/262 [==============================] - ETA: 0s - loss: 0.5758 - accuracy: 0.8354
# Epoch 13: val_accuracy did not improve from 0.71429
# 262/262 [==============================] - 166s 634ms/step - loss: 0.5758 - accuracy: 0.8354 - val_loss: 0.9670 - val_accuracy: 0.6794
# Epoch 14/20
# 262/262 [==============================] - ETA: 0s - loss: 0.5949 - accuracy: 0.8449
# Epoch 14: val_accuracy did not improve from 0.71429
# 262/262 [==============================] - 168s 642ms/step - loss: 0.5949 - accuracy: 0.8449 - val_loss: 1.0342 - val_accuracy: 0.6813
# Epoch 15/20
# 262/262 [==============================] - ETA: 0s - loss: 0.6373 - accuracy: 0.8519
# Epoch 15: val_accuracy did not improve from 0.71429
# 262/262 [==============================] - 167s 636ms/step - loss: 0.6373 - accuracy: 0.8519 - val_loss: 1.1272 - val_accuracy: 0.7124
# Epoch 16/20
# 262/262 [==============================] - ETA: 0s - loss: 0.6969 - accuracy: 0.8631
# Epoch 16: val_accuracy did not improve from 0.71429
# 262/262 [==============================] - 177s 676ms/step - loss: 0.6969 - accuracy: 0.8631 - val_loss: 1.1186 - val_accuracy: 0.7000
# Epoch 17/20
# 262/262 [==============================] - ETA: 0s - loss: 0.7344 - accuracy: 0.8697
# Epoch 17: val_accuracy improved from 0.71429 to 0.71906, saving model to lstm_model.hdf5
# 262/262 [==============================] - 176s 674ms/step - loss: 0.7344 - accuracy: 0.8697 - val_loss: 1.2174 - val_accuracy: 0.7191
# Epoch 18/20
# 262/262 [==============================] - ETA: 0s - loss: 0.8365 - accuracy: 0.8639
# Epoch 18: val_accuracy improved from 0.71906 to 0.72480, saving model to lstm_model.hdf5
# 262/262 [==============================] - 165s 632ms/step - loss: 0.8365 - accuracy: 0.8639 - val_loss: 1.4090 - val_accuracy: 0.7248
# Epoch 19/20
# 262/262 [==============================] - ETA: 0s - loss: 0.9418 - accuracy: 0.8682
# Epoch 19: val_accuracy did not improve from 0.72480
# 262/262 [==============================] - 167s 638ms/step - loss: 0.9418 - accuracy: 0.8682 - val_loss: 1.5078 - val_accuracy: 0.7162
# Epoch 20/20
# 262/262 [==============================] - ETA: 0s - loss: 0.9937 - accuracy: 0.8731
# Epoch 20: val_accuracy did not improve from 0.72480
# 262/262 [==============================] - 178s 681ms/step - loss: 0.9937 - accuracy: 0.8731 - val_loss: 1.5754 - val_accuracy: 0.7109

# %%
import tensorflow as tf
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
# Evaluate the model
y_pred = model.predict([X_test_review, X_test_aspect])
y_pred = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

# Classification report
print(classification_report(y_true, y_pred))

# Confusion matrix
cm = confusion_matrix(y_true, y_pred)
print(cm)

# Accuracy
accuracy = accuracy_score(y_true, y_pred)
print("Accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# 66/66 [==============================] - 13s 166ms/step
#               precision    recall  f1-score   support
#
#            0       0.58      0.51      0.54       422
#            1       0.65      0.56      0.60       528
#            2       0.77      0.86      0.81      1143
#
#     accuracy                           0.71      2093
#    macro avg       0.67      0.64      0.65      2093
# weighted avg       0.70      0.71      0.70      2093
#
# [[214  56 152]
#  [ 99 294 135]
#  [ 59 104 980]]
# Accuracy: 71.09%

# %%
# ROC curve
y_scores = model.predict([X_test_review, X_test_aspect])
fpr, tpr, _ = roc_curve(y_test.ravel(), y_scores.ravel())
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# 66/66 [==============================] - 11s 172ms/step

# %%
# Plot accuracy and loss over epochs
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
